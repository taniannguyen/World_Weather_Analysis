# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0c31434299f1a4a0fce1a5bfa1b251f4

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | rio gallegos
# Processing Record 3 of Set 1 | psebay
# Processing Record 4 of Set 1 | gambo
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | soyo
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | tabuk
# Processing Record 11 of Set 1 | saveh
# Processing Record 12 of Set 1 | chumphon
# Processing Record 13 of Set 1 | santo tomas
# Processing Record 14 of Set 1 | surat
# Processing Record 15 of Set 1 | baherden
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | chipata
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | olafsvik
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | lima
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | vryburg
# Processing Record 38 of Set 1 | safita
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | shamkhal
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | turukhansk
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | zima
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | poum
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | kamyzyak
# Processing Record 3 of Set 2 | margate
# Processing Record 4 of Set 2 | humaita
# Processing Record 5 of Set 2 | sept-iles
# Processing Record 6 of Set 2 | mortka
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | curuca
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | atambua
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | nova ushytsya
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | mwinilunga
# Processing Record 20 of Set 2 | oistins
# Processing Record 21 of Set 2 | alice springs
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | boffa
# Processing Record 26 of Set 2 | corozal
# Processing Record 27 of Set 2 | vao
# Processing Record 28 of Set 2 | pathardi
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | san quintin
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 2 | panzhihua
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | vardo
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | palmer
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | marsa matruh
# Processing Record 43 of Set 2 | soyaux
# Processing Record 44 of Set 2 | kuching
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | qasigiannguit
# Processing Record 47 of Set 2 | carutapera
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | hasaki
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | westport
# Processing Record 3 of Set 3 | neepawa
# Processing Record 4 of Set 3 | oudtshoorn
# Processing Record 5 of Set 3 | pangody
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | koson
# Processing Record 8 of Set 3 | thinadhoo
# Processing Record 9 of Set 3 | llaillay
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | ahipara
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | zherdevka
# Processing Record 14 of Set 3 | saint anthony
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | huanren
# Processing Record 17 of Set 3 | san carlos de bariloche
# Processing Record 18 of Set 3 | flinders
# Processing Record 19 of Set 3 | sechura
# Processing Record 20 of Set 3 | muros
# Processing Record 21 of Set 3 | hay river
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | sikasso
# Processing Record 24 of Set 3 | dauriya
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | gisborne
# Processing Record 27 of Set 3 | beidao
# Processing Record 28 of Set 3 | acapulco
# Processing Record 29 of Set 3 | cabo san lucas
# Processing Record 30 of Set 3 | macamic
# Processing Record 31 of Set 3 | alofi
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | gambela
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | toora-khem
# Processing Record 38 of Set 3 | kapaa
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | velyka pysarivka
# Processing Record 41 of Set 3 | progreso
# Processing Record 42 of Set 3 | bayamo
# Processing Record 43 of Set 3 | el dovio
# Processing Record 44 of Set 3 | zhoucheng
# Processing Record 45 of Set 3 | lake city
# Processing Record 46 of Set 3 | kyra
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | gombe
# Processing Record 49 of Set 3 | moerai
# Processing Record 50 of Set 3 | namie
# Processing Record 1 of Set 4 | acarau
# Processing Record 2 of Set 4 | vanavara
# Processing Record 3 of Set 4 | yarmouth
# Processing Record 4 of Set 4 | kure
# Processing Record 5 of Set 4 | zarautz
# Processing Record 6 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 4 | atar
# Processing Record 8 of Set 4 | sovetskiy
# Processing Record 9 of Set 4 | tessalit
# Processing Record 10 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 11 of Set 4 | winnemucca
# Processing Record 12 of Set 4 | hereford
# Processing Record 13 of Set 4 | ulladulla
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 4 | egvekinot
# Processing Record 17 of Set 4 | anito
# Processing Record 18 of Set 4 | asahi
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | champerico
# Processing Record 22 of Set 4 | berezovka
# Processing Record 23 of Set 4 | mandalgovi
# Processing Record 24 of Set 4 | lasa
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | broken hill
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | upernavik
# Processing Record 29 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 4 | okmulgee
# Processing Record 31 of Set 4 | fomboni
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | arica
# Processing Record 36 of Set 4 | aswan
# Processing Record 37 of Set 4 | arzgir
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | moen
# Processing Record 40 of Set 4 | rochegda
# Processing Record 41 of Set 4 | kununurra
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | antofagasta
# Processing Record 45 of Set 4 | tawang
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | mineros
# Processing Record 48 of Set 4 | baoning
# Processing Record 49 of Set 4 | grindavik
# Processing Record 50 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 5 | paris
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | pitsunda
# Processing Record 4 of Set 5 | khuzhir
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | mogadishu
# Processing Record 7 of Set 5 | coahuayana
# Processing Record 8 of Set 5 | arraial do cabo
# Processing Record 9 of Set 5 | brigantine
# Processing Record 10 of Set 5 | nagorsk
# Processing Record 11 of Set 5 | atuona
# Processing Record 12 of Set 5 | tyrma
# Processing Record 13 of Set 5 | hambantota
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | bubaque
# Processing Record 16 of Set 5 | sao gabriel
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | akureyri
# Processing Record 19 of Set 5 | bitung
# Processing Record 20 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 5 | tilichiki
# Processing Record 22 of Set 5 | sarevere
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | bullhead city
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | bloomfield
# Processing Record 27 of Set 5 | srednekolymsk
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | sandpoint
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | komsomolskiy
# Processing Record 32 of Set 5 | marawi
# Processing Record 33 of Set 5 | nuevo progreso
# Processing Record 34 of Set 5 | tiksi
# Processing Record 35 of Set 5 | broome
# Processing Record 36 of Set 5 | waynesboro
# Processing Record 37 of Set 5 | forest
# Processing Record 38 of Set 5 | mao
# Processing Record 39 of Set 5 | mattru
# Processing Record 40 of Set 5 | roald
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | asau
# Processing Record 43 of Set 5 | magaramkent
# Processing Record 44 of Set 5 | inuvik
# Processing Record 45 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | ambon
# Processing Record 47 of Set 5 | shanting
# Processing Record 48 of Set 5 | codrington
# Processing Record 49 of Set 5 | haines junction
# Processing Record 50 of Set 5 | narsaq
# Processing Record 1 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 6 | abu samrah
# Processing Record 3 of Set 6 | bakaly
# Processing Record 4 of Set 6 | itacoatiara
# Processing Record 5 of Set 6 | roswell
# Processing Record 6 of Set 6 | sorkjosen
# Processing Record 7 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 6 | monte cristi
# City not found. Skipping...
# Processing Record 9 of Set 6 | namwala
# Processing Record 10 of Set 6 | san cristobal
# Processing Record 11 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 6 | puerto leguizamo
# Processing Record 13 of Set 6 | faya
# Processing Record 14 of Set 6 | grenville
# Processing Record 15 of Set 6 | agadir
# Processing Record 16 of Set 6 | henties bay
# Processing Record 17 of Set 6 | alugan
# Processing Record 18 of Set 6 | avarua
# Processing Record 19 of Set 6 | chuy
# Processing Record 20 of Set 6 | kuito
# Processing Record 21 of Set 6 | veraval
# Processing Record 22 of Set 6 | lufilufi
# Processing Record 23 of Set 6 | ribeira brava
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | talnakh
# Processing Record 26 of Set 6 | piste
# Processing Record 27 of Set 6 | salalah
# Processing Record 28 of Set 6 | lugo
# Processing Record 29 of Set 6 | la ronge
# Processing Record 30 of Set 6 | toucheng
# Processing Record 31 of Set 6 | meulaboh
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 6 | geraldton
# Processing Record 35 of Set 6 | birao
# Processing Record 36 of Set 6 | aromashevo
# Processing Record 37 of Set 6 | horasan
# Processing Record 38 of Set 6 | youghal
# Processing Record 39 of Set 6 | panguna
# Processing Record 40 of Set 6 | santa isabel do rio negro
# Processing Record 41 of Set 6 | port alfred
# Processing Record 42 of Set 6 | saint-philippe
# Processing Record 43 of Set 6 | saint-francois
# Processing Record 44 of Set 6 | kurilsk
# Processing Record 45 of Set 6 | lugovoy
# Processing Record 46 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 6 | lebu
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | krasnoselkup
# Processing Record 50 of Set 6 | salta
# Processing Record 1 of Set 7 | pyay
# Processing Record 2 of Set 7 | ende
# Processing Record 3 of Set 7 | anadyr
# Processing Record 4 of Set 7 | beloha
# Processing Record 5 of Set 7 | taltal
# Processing Record 6 of Set 7 | andenes
# Processing Record 7 of Set 7 | boa vista
# Processing Record 8 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | kimbe
# Processing Record 11 of Set 7 | rincon
# Processing Record 12 of Set 7 | esso
# Processing Record 13 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 7 | bilma
# Processing Record 15 of Set 7 | nishihara
# Processing Record 16 of Set 7 | cozumel
# Processing Record 17 of Set 7 | matara
# Processing Record 18 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 7 | ayagoz
# Processing Record 20 of Set 7 | simpang
# Processing Record 21 of Set 7 | saint-pierre
# Processing Record 22 of Set 7 | orel-izumrud
# Processing Record 23 of Set 7 | buala
# Processing Record 24 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 7 | cercany
# Processing Record 26 of Set 7 | inverell
# Processing Record 27 of Set 7 | borazjan
# Processing Record 28 of Set 7 | kidal
# Processing Record 29 of Set 7 | pampa
# Processing Record 30 of Set 7 | bowen
# Processing Record 31 of Set 7 | kaliwungu
# Processing Record 32 of Set 7 | hobyo
# Processing Record 33 of Set 7 | port augusta
# Processing Record 34 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 7 | vila franca do campo
# Processing Record 36 of Set 7 | koplik
# Processing Record 37 of Set 7 | maun
# Processing Record 38 of Set 7 | montevideo
# Processing Record 39 of Set 7 | auki
# Processing Record 40 of Set 7 | itoman
# Processing Record 41 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 7 | hervey bay
# Processing Record 43 of Set 7 | alyangula
# Processing Record 44 of Set 7 | namibe
# Processing Record 45 of Set 7 | novikovo
# Processing Record 46 of Set 7 | sumenep
# Processing Record 47 of Set 7 | beringovskiy
# Processing Record 48 of Set 7 | tautira
# Processing Record 49 of Set 7 | coihaique
# Processing Record 50 of Set 7 | pimentel
# Processing Record 1 of Set 8 | noumea
# Processing Record 2 of Set 8 | ljungby
# Processing Record 3 of Set 8 | vizinga
# Processing Record 4 of Set 8 | gat
# Processing Record 5 of Set 8 | acajutla
# Processing Record 6 of Set 8 | meadow lake
# Processing Record 7 of Set 8 | sao jose da coroa grande
# Processing Record 8 of Set 8 | lavrentiya
# Processing Record 9 of Set 8 | kartuzy
# Processing Record 10 of Set 8 | viedma
# Processing Record 11 of Set 8 | balakhninskiy
# Processing Record 12 of Set 8 | guhagar
# Processing Record 13 of Set 8 | kishi
# Processing Record 14 of Set 8 | chingirlau
# Processing Record 15 of Set 8 | den helder
# Processing Record 16 of Set 8 | cayenne
# Processing Record 17 of Set 8 | farah
# Processing Record 18 of Set 8 | honningsvag
# Processing Record 19 of Set 8 | cocobeach
# Processing Record 20 of Set 8 | bulgan
# Processing Record 21 of Set 8 | yaan
# Processing Record 22 of Set 8 | esperance
# Processing Record 23 of Set 8 | melhus
# Processing Record 24 of Set 8 | suntar
# Processing Record 25 of Set 8 | awbari
# Processing Record 26 of Set 8 | sola
# Processing Record 27 of Set 8 | jiamusi
# Processing Record 28 of Set 8 | tiarei
# Processing Record 29 of Set 8 | lensk
# Processing Record 30 of Set 8 | ancud
# Processing Record 31 of Set 8 | bundaberg
# Processing Record 32 of Set 8 | mangrul pir
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | obidos
# Processing Record 35 of Set 8 | bonthe
# Processing Record 36 of Set 8 | umm lajj
# Processing Record 37 of Set 8 | khatanga
# Processing Record 38 of Set 8 | zhezkazgan
# Processing Record 39 of Set 8 | himora
# City not found. Skipping...
# Processing Record 40 of Set 8 | aden
# Processing Record 41 of Set 8 | esmeraldas
# Processing Record 42 of Set 8 | springbok
# Processing Record 43 of Set 8 | savalou
# Processing Record 44 of Set 8 | quepos
# Processing Record 45 of Set 8 | santa cruz do capibaribe
# Processing Record 46 of Set 8 | lethem
# Processing Record 47 of Set 8 | florianopolis
# Processing Record 48 of Set 8 | waipawa
# Processing Record 49 of Set 8 | pangnirtung
# Processing Record 50 of Set 8 | angoram
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | sambava
# Processing Record 3 of Set 9 | tinskoy
# Processing Record 4 of Set 9 | mombaca
# Processing Record 5 of Set 9 | siwana
# Processing Record 6 of Set 9 | along
# Processing Record 7 of Set 9 | nouadhibou
# Processing Record 8 of Set 9 | ler
# Processing Record 9 of Set 9 | kodiak
# Processing Record 10 of Set 9 | wajima
# Processing Record 11 of Set 9 | slave lake
# Processing Record 12 of Set 9 | izegem
# Processing Record 13 of Set 9 | poya
# Processing Record 14 of Set 9 | hassan
# Processing Record 15 of Set 9 | tulum
# Processing Record 16 of Set 9 | xiaoweizhai
# Processing Record 17 of Set 9 | salina cruz
# Processing Record 18 of Set 9 | sestri levante
# Processing Record 19 of Set 9 | svetlogorsk
# Processing Record 20 of Set 9 | constitucion
# Processing Record 21 of Set 9 | hovd
# Processing Record 22 of Set 9 | jardim
# Processing Record 23 of Set 9 | chipinge
# Processing Record 24 of Set 9 | dingle
# Processing Record 25 of Set 9 | tazovskiy
# Processing Record 26 of Set 9 | wheeling
# Processing Record 27 of Set 9 | shingu
# Processing Record 28 of Set 9 | brawley
# Processing Record 29 of Set 9 | lalitpur
# Processing Record 30 of Set 9 | yumen
# Processing Record 31 of Set 9 | quatre cocos
# Processing Record 32 of Set 9 | shakawe
# Processing Record 33 of Set 9 | am timan
# Processing Record 34 of Set 9 | fairbanks
# Processing Record 35 of Set 9 | maceio
# Processing Record 36 of Set 9 | san luis
# Processing Record 37 of Set 9 | kahului
# Processing Record 38 of Set 9 | berdigestyakh
# Processing Record 39 of Set 9 | sorland
# Processing Record 40 of Set 9 | rosetta
# Processing Record 41 of Set 9 | dorogobuzh
# Processing Record 42 of Set 9 | kinsale
# Processing Record 43 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 9 | rocha
# Processing Record 45 of Set 9 | hofn
# Processing Record 46 of Set 9 | northam
# Processing Record 47 of Set 9 | huambo
# Processing Record 48 of Set 9 | la serena
# Processing Record 49 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 9 | ponta delgada
# Processing Record 1 of Set 10 | luganville
# Processing Record 2 of Set 10 | bratsk
# Processing Record 3 of Set 10 | labuhan
# Processing Record 4 of Set 10 | mombetsu
# Processing Record 5 of Set 10 | mandurah
# Processing Record 6 of Set 10 | burica
# City not found. Skipping...
# Processing Record 7 of Set 10 | boutersem
# Processing Record 8 of Set 10 | kurchum
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | vylgort
# City not found. Skipping...
# Processing Record 11 of Set 10 | port lincoln
# Processing Record 12 of Set 10 | la romana
# Processing Record 13 of Set 10 | berlevag
# Processing Record 14 of Set 10 | saint-joseph
# Processing Record 15 of Set 10 | payo
# Processing Record 16 of Set 10 | inirida
# Processing Record 17 of Set 10 | manokwari
# Processing Record 18 of Set 10 | kushmurun
# Processing Record 19 of Set 10 | tura
# Processing Record 20 of Set 10 | prainha
# Processing Record 21 of Set 10 | kenai
# Processing Record 22 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 10 | hualmay
# Processing Record 24 of Set 10 | skjervoy
# Processing Record 25 of Set 10 | japura
# Processing Record 26 of Set 10 | tamiahua
# Processing Record 27 of Set 10 | garoua
# Processing Record 28 of Set 10 | manadhoo
# Processing Record 29 of Set 10 | yenagoa
# Processing Record 30 of Set 10 | palmeiras de goias
# Processing Record 31 of Set 10 | avera
# Processing Record 32 of Set 10 | salumbar
# Processing Record 33 of Set 10 | yima
# Processing Record 34 of Set 10 | wanning
# Processing Record 35 of Set 10 | christchurch
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | quincy
# Processing Record 38 of Set 10 | nabire
# Processing Record 39 of Set 10 | gamba
# Processing Record 40 of Set 10 | seoul
# Processing Record 41 of Set 10 | tommot
# Processing Record 42 of Set 10 | urumqi
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | aksarka
# Processing Record 45 of Set 10 | puerto lempira
# Processing Record 46 of Set 10 | morondava
# Processing Record 47 of Set 10 | cabinda
# Processing Record 48 of Set 10 | weligama
# Processing Record 49 of Set 10 | vyritsa
# Processing Record 50 of Set 10 | kashi
# Processing Record 1 of Set 11 | namatanai
# Processing Record 2 of Set 11 | vostok
# Processing Record 3 of Set 11 | venice
# Processing Record 4 of Set 11 | laguna
# Processing Record 5 of Set 11 | pietarsaari
# Processing Record 6 of Set 11 | requena
# Processing Record 7 of Set 11 | mega
# Processing Record 8 of Set 11 | thaton
# Processing Record 9 of Set 11 | oktyabrskiy
# Processing Record 10 of Set 11 | escanaba
# Processing Record 11 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 12 of Set 11 | hala
# Processing Record 13 of Set 11 | baruun-urt
# Processing Record 14 of Set 11 | pajacuaran
# Processing Record 15 of Set 11 | kieta
# Processing Record 16 of Set 11 | tecoanapa
# Processing Record 17 of Set 11 | bobonong
# City not found. Skipping...
# Processing Record 18 of Set 11 | yulara
# Processing Record 19 of Set 11 | mount gambier
# Processing Record 20 of Set 11 | mikuni
# Processing Record 21 of Set 11 | ligayan
# Processing Record 22 of Set 11 | fernley
# Processing Record 23 of Set 11 | katherine
# Processing Record 24 of Set 11 | mashivka
# Processing Record 25 of Set 11 | gbadolite
# Processing Record 26 of Set 11 | corralillo
# Processing Record 27 of Set 11 | barquisimeto
# Processing Record 28 of Set 11 | backi petrovac
# Processing Record 29 of Set 11 | maridi
# Processing Record 30 of Set 11 | lingao
# Processing Record 31 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | bonfim
# Processing Record 33 of Set 11 | chabahar
# Processing Record 34 of Set 11 | lagoa
# Processing Record 35 of Set 11 | tyukalinsk
# Processing Record 36 of Set 11 | nalobikha
# Processing Record 37 of Set 11 | zhangye
# Processing Record 38 of Set 11 | pizarro
# Processing Record 39 of Set 11 | bengkulu
# Processing Record 40 of Set 11 | arbazh
# Processing Record 41 of Set 11 | vitim
# Processing Record 42 of Set 11 | le mars
# Processing Record 43 of Set 11 | kalat
# Processing Record 44 of Set 11 | kihei
# Processing Record 45 of Set 11 | moron
# Processing Record 46 of Set 11 | nemuro
# Processing Record 47 of Set 11 | troitsko-pechorsk
# Processing Record 48 of Set 11 | saint-augustin
# Processing Record 49 of Set 11 | zatoka
# Processing Record 50 of Set 11 | peniche
# Processing Record 1 of Set 12 | talara
# Processing Record 2 of Set 12 | eureka
# Processing Record 3 of Set 12 | tara
# Processing Record 4 of Set 12 | luz
# Processing Record 5 of Set 12 | khasan
# Processing Record 6 of Set 12 | naifaru
# Processing Record 7 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 8 of Set 12 | smithers
# Processing Record 9 of Set 12 | kano
# Processing Record 10 of Set 12 | irtyshskiy
# Processing Record 11 of Set 12 | te anau
# Processing Record 12 of Set 12 | lemgo
# Processing Record 13 of Set 12 | jamame
# Processing Record 14 of Set 12 | yangambi
# Processing Record 15 of Set 12 | buarcos
# Processing Record 16 of Set 12 | kavaratti
# Processing Record 17 of Set 12 | morros
# Processing Record 18 of Set 12 | tevaitoa
# Processing Record 19 of Set 12 | mjolby
# Processing Record 20 of Set 12 | marsh harbour
# Processing Record 21 of Set 12 | safaga
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | piracaia
# Processing Record 24 of Set 12 | poronaysk
# Processing Record 25 of Set 12 | ciudad guayana
# Processing Record 26 of Set 12 | fort nelson
# Processing Record 27 of Set 12 | gorontalo
# Processing Record 28 of Set 12 | kutum
# Processing Record 29 of Set 12 | zhengjiatun
# Processing Record 30 of Set 12 | otane
# Processing Record 31 of Set 12 | nha trang
# Processing Record 32 of Set 12 | vestmannaeyjar
# Processing Record 33 of Set 12 | sao joao da barra
# Processing Record 34 of Set 12 | deputatskiy
# Processing Record 35 of Set 12 | cotonou
# Processing Record 36 of Set 12 | tanakpur
# Processing Record 37 of Set 12 | sault sainte marie
# Processing Record 38 of Set 12 | jacutinga
# Processing Record 39 of Set 12 | bathsheba
# Processing Record 40 of Set 12 | winneba
# Processing Record 41 of Set 12 | sarany
# Processing Record 42 of Set 12 | roma
# Processing Record 43 of Set 12 | ucluelet
# Processing Record 44 of Set 12 | gashua
# Processing Record 45 of Set 12 | deulgaon raja
# Processing Record 46 of Set 12 | port macquarie
# Processing Record 47 of Set 12 | endicott
# Processing Record 48 of Set 12 | ust-nera
# Processing Record 49 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 50 of Set 12 | qui nhon
# Processing Record 1 of Set 13 | lata
# Processing Record 2 of Set 13 | grand gaube
# Processing Record 3 of Set 13 | maragogi
# Processing Record 4 of Set 13 | vaitape
# Processing Record 5 of Set 13 | linxia
# Processing Record 6 of Set 13 | phalombe
# Processing Record 7 of Set 13 | pichayevo
# Processing Record 8 of Set 13 | huilong
# Processing Record 9 of Set 13 | hienghene
# Processing Record 10 of Set 13 | sioux lookout
# Processing Record 11 of Set 13 | amahai
# Processing Record 12 of Set 13 | tuy hoa
# Processing Record 13 of Set 13 | cap malheureux
# Processing Record 14 of Set 13 | loiza
# Processing Record 15 of Set 13 | fortuna
# Processing Record 16 of Set 13 | sallanches
# Processing Record 17 of Set 13 | angoche
# Processing Record 18 of Set 13 | kemijarvi
# Processing Record 19 of Set 13 | mezhdurechensk
# Processing Record 20 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 13 | sivas
# Processing Record 22 of Set 13 | adrar
# Processing Record 23 of Set 13 | kawalu
# Processing Record 24 of Set 13 | tornio
# Processing Record 25 of Set 13 | conde
# Processing Record 26 of Set 13 | gejiu
# Processing Record 27 of Set 13 | turayf
# Processing Record 28 of Set 13 | mazamari
# Processing Record 29 of Set 13 | kraljevo
# Processing Record 30 of Set 13 | bogorodskoye
# Processing Record 31 of Set 13 | khawhai
# Processing Record 32 of Set 13 | itarema
# Processing Record 33 of Set 13 | leiyang
# Processing Record 34 of Set 13 | guerrero negro
# Processing Record 35 of Set 13 | goderich
# Processing Record 36 of Set 13 | burgeo
# Processing Record 37 of Set 13 | kropotkin
# Processing Record 38 of Set 13 | lamu
# Processing Record 39 of Set 13 | orlik
# Processing Record 40 of Set 13 | calafell
# Processing Record 41 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 43 of Set 13 | xining
# Processing Record 44 of Set 13 | santa cruz
# Processing Record 45 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 13 | bam
# Processing Record 48 of Set 13 | maturin
# Processing Record 49 of Set 13 | harbour breton
# Processing Record 50 of Set 13 | empalme
# Processing Record 1 of Set 14 | batticaloa
# Processing Record 2 of Set 14 | teguise
# Processing Record 3 of Set 14 | goundam
# Processing Record 4 of Set 14 | brae
# Processing Record 5 of Set 14 | grand-santi
# Processing Record 6 of Set 14 | souris
# Processing Record 7 of Set 14 | tra vinh
# Processing Record 8 of Set 14 | adet
# Processing Record 9 of Set 14 | galle
# Processing Record 10 of Set 14 | waynesville
# Processing Record 11 of Set 14 | labytnangi
# Processing Record 12 of Set 14 | kavieng
# Processing Record 13 of Set 14 | catalina foothills
# Processing Record 14 of Set 14 | dulovo
# Processing Record 15 of Set 14 | ketchikan
# Processing Record 16 of Set 14 | bhunya
# Processing Record 17 of Set 14 | vallenar
# Processing Record 18 of Set 14 | dvinskoy
# Processing Record 19 of Set 14 | magadan
# Processing Record 20 of Set 14 | wampusirpi
# City not found. Skipping...
# Processing Record 21 of Set 14 | port-cartier
# Processing Record 22 of Set 14 | waingapu
# Processing Record 23 of Set 14 | aguililla
# Processing Record 24 of Set 14 | salinas
# Processing Record 25 of Set 14 | oranjemund
# Processing Record 26 of Set 14 | mana
# Processing Record 27 of Set 14 | phek
# Processing Record 28 of Set 14 | alekseyevsk
# Processing Record 29 of Set 14 | tabou
# Processing Record 30 of Set 14 | kathu
# Processing Record 31 of Set 14 | oriximina
# Processing Record 32 of Set 14 | harper
# Processing Record 33 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 34 of Set 14 | snezhnogorsk
# Processing Record 35 of Set 14 | sorgun
# Processing Record 36 of Set 14 | mukhen
# Processing Record 37 of Set 14 | ozernovskiy
# Processing Record 38 of Set 14 | sibu
# Processing Record 39 of Set 14 | omboue
# Processing Record 40 of Set 14 | araouane
# Processing Record 41 of Set 14 | lyuban
# Processing Record 42 of Set 14 | olinda
# Processing Record 43 of Set 14 | snasa
# Processing Record 44 of Set 14 | port hedland
# Processing Record 45 of Set 14 | tagusao
# Processing Record 46 of Set 14 | mumford
# Processing Record 47 of Set 14 | pisz
# Processing Record 48 of Set 14 | north kessock
# Processing Record 49 of Set 14 | rundu
# Processing Record 50 of Set 14 | juodupe
# Processing Record 1 of Set 15 | nehe
# Processing Record 2 of Set 15 | marovoay
# Processing Record 3 of Set 15 | aykhal
# Processing Record 4 of Set 15 | paranaiba
# Processing Record 5 of Set 15 | kommunisticheskiy
# Processing Record 6 of Set 15 | keti bandar
# Processing Record 7 of Set 15 | jacqueville
# Processing Record 8 of Set 15 | the valley
# Processing Record 9 of Set 15 | cumra
# Processing Record 10 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 15 | prince george
# Processing Record 12 of Set 15 | mugur-aksy
# Processing Record 13 of Set 15 | calama
# Processing Record 14 of Set 15 | rio branco
# Processing Record 15 of Set 15 | nyurba
# Processing Record 16 of Set 15 | liminangcong
# City not found. Skipping...
# Processing Record 17 of Set 15 | paramirim
# Processing Record 18 of Set 15 | sirpur
# Processing Record 19 of Set 15 | naryan-mar
# Processing Record 20 of Set 15 | ayr
# Processing Record 21 of Set 15 | ankazoabo
# Processing Record 22 of Set 15 | thap than
# Processing Record 23 of Set 15 | roura
# Processing Record 24 of Set 15 | asyut
# Processing Record 25 of Set 15 | monterey
# Processing Record 26 of Set 15 | college
# Processing Record 27 of Set 15 | alta floresta
# Processing Record 28 of Set 15 | fare
# Processing Record 29 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 15 | jacobabad
# Processing Record 31 of Set 15 | whitianga
# Processing Record 32 of Set 15 | barcelos
# Processing Record 33 of Set 15 | aasiaat
# Processing Record 34 of Set 15 | tiznit
# Processing Record 35 of Set 15 | russell
# Processing Record 36 of Set 15 | pio ix
# Processing Record 37 of Set 15 | invermere
# Processing Record 38 of Set 15 | natal
# Processing Record 39 of Set 15 | sri aman
# Processing Record 40 of Set 15 | yerbogachen
# Processing Record 41 of Set 15 | portland
# Processing Record 42 of Set 15 | alakurtti
# Processing Record 43 of Set 15 | tsogni
# Processing Record 44 of Set 15 | henderson
# Processing Record 45 of Set 15 | kaseda
# Processing Record 46 of Set 15 | cantanhede
# Processing Record 47 of Set 15 | port blair
# Processing Record 48 of Set 15 | synya
# Processing Record 49 of Set 15 | butterworth
# Processing Record 50 of Set 15 | tallahassee
# Processing Record 1 of Set 16 | fort saint james
# Processing Record 2 of Set 16 | aksu
# Processing Record 3 of Set 16 | nalut
# Processing Record 4 of Set 16 | shar
# Processing Record 5 of Set 16 | tevriz
# Processing Record 6 of Set 16 | kaminskiy
# Processing Record 7 of Set 16 | shakiso
# Processing Record 8 of Set 16 | ixtapa
# Processing Record 9 of Set 16 | iranshahr
# Processing Record 10 of Set 16 | keighley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Butaritari   3.07  172.79     83.03        73         100       17.96
# 1  Rio Gallegos -51.62  -69.22     44.60        52          75       10.29
# 2        Psebay  44.12   40.81     62.69        85          63        3.78
# 3         Gambo   4.65   22.26     71.40        94          62        2.57
# 4        Albany  42.60  -73.97     72.00        52          30        2.37
# 5       Ushuaia -54.80  -68.30     42.80        75          75       23.04
# 6          Soyo  -6.13   12.37     77.00        83          75        8.05
# 7       Aklavik  68.22 -135.01     41.00        80          75        6.93
# 8  Punta Arenas -53.15  -70.92     44.60        70          75       21.92
# 9         Tabuk  17.42  121.44     75.16        86         100        2.26
#
#   Country      Current Description
# 0      KI          overcast clouds
# 1      AR            broken clouds
# 2      RU            broken clouds
# 3      CF               light rain
# 4      US         scattered clouds
# 5      AR  light intensity drizzle
# 6      AO            broken clouds
# 7      CA            broken clouds
# 8      CL            broken clouds
# 9      PH          overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df [new_column_order]
city_data_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari      KI   3.07  172.79     83.03        73         100
# 1  Rio Gallegos      AR -51.62  -69.22     44.60        52          75
# 2        Psebay      RU  44.12   40.81     62.69        85          63
# 3         Gambo      CF   4.65   22.26     71.40        94          62
# 4        Albany      US  42.60  -73.97     72.00        52          30
#
#    Wind Speed Current Description
# 0       17.96     overcast clouds
# 1       10.29       broken clouds
# 2        3.78       broken clouds
# 3        2.57          light rain
# 4        2.37    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
